# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharpoint2/Spotify-New-Release-Finder/blob/main/New_Release_Finder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import base64
import time
from urllib.parse import urlencode

# --- Your Spotify API Credentials ---
# Replace these with the credentials from your Spotify Developer Dashboard App
CLIENT_ID = "CLIENT_ID"
CLIENT_SECRET = "CLIENT_SECRET"
# ------------------------------------

# --- Customize Your Search ---
# Add or remove genres to tailor your search for new releases.
GENRE_LIST = [
    "rock", "alt-rock", "indie", "punk", "hardcore",
    "metal", "death-metal", "black-metal", "deathcore",
    "hip-hop", "trap","rap",
    "pop", "synth-pop",
    "electronic", "techno", "house", "ambient",
    "jazz", "soul", "funk", "blues",
    "classical", "folk", "country", "metalcore"
]
# -----------------------------


def get_spotify_token(client_id, client_secret):
    """Gets an access token from the Spotify API."""
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode('utf-8')).decode('utf-8')
    headers = {'Authorization': f'Basic {auth_header}'}
    data = {'grant_type': 'client_credentials'}
    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Error getting token: {response.status_code} - {response.text}")
        return None

def search_new_releases_by_genre(token, genres):
    """Searches for new releases across a list of genres, correctly handling pagination."""
    all_new_releases = []
    seen_album_ids = set()

    headers = {'Authorization': f'Bearer {token}'}
    base_search_url = 'https://api.spotify.com/v1/search'

    for genre in genres:
        print(f"\nSearching for new releases in genre: '{genre}'...")

        # --- THE FIX IS IMPLEMENTED HERE ---

        # 1. Start with the base URL and the parameters for the first search.
        next_url = base_search_url
        params = {
            'q': f'genre:"{genre}" tag:new',
            'type': 'album',
            'limit': 50
        }

        # Loop to handle all pages of results for the current genre
        while next_url:
            # 2. Make the request using the URL and any available params.
            # The `requests` library correctly handles if `params` is None.
            response = requests.get(next_url, headers=headers, params=params)

            # 3. CRITICAL: Clear the params after the first request.
            # The 'next_url' from Spotify contains all needed parameters,
            # so we must not send them again.
            if params:
                params = None

            if response.status_code == 200:
                data = response.json()
                albums = data.get('albums', {}).get('items', [])

                found_count = 0
                for album in albums:
                    if album['id'] not in seen_album_ids:
                        all_new_releases.append(album)
                        seen_album_ids.add(album['id'])
                        found_count += 1

                if found_count > 0:
                    print(f"   > Found {found_count} new unique releases.")

                # Get the URL for the next page of results
                next_url = data.get('albums', {}).get('next')
                time.sleep(0.1)
            elif response.status_code == 429:
                retry_after = int(response.headers.get('Retry-After', 1))
                print(f"   > Rate limit hit. Waiting for {retry_after} seconds...")
                time.sleep(retry_after)
            else:
                print(f"   > Error searching for genre '{genre}': {response.status_code} - {response.text}")
                break # Stop searching this genre if an error occurs

    return all_new_releases

def display_releases(releases):
    """Prints the list of releases in a readable format."""
    if not releases:
        print("No releases found or an error occurred.")
        return

    print("\n\n--- 🎸 A More Comprehensive List of New Releases ---")

    # Sort releases by release date, most recent first
    releases.sort(key=lambda x: x['release_date'], reverse=True)

    for i, item in enumerate(releases, 1):
        album_type = item['album_type'].capitalize()
        album_name = item['name']
        release_date = item['release_date']
        artist_names = ', '.join([artist['name'] for artist in item['artists']])
        spotify_url = item['external_urls']['spotify']

        print(f"\n{i}. [{album_type}] {artist_names} - {album_name}")
        print(f"   Released: {release_date}")
        print(f"   Listen here: {spotify_url}")

    print(f"\n--- Total Unique Releases Found: {len(releases)} ---")


if __name__ == "__main__":
    if CLIENT_ID == "YOUR_CLIENT_ID_HERE" or CLIENT_SECRET == "YOUR_CLIENT_SECRET_HERE":
        print("🛑 ERROR: Please replace the placeholder credentials in the script.")
    else:
        access_token = get_spotify_token(CLIENT_ID, CLIENT_SECRET)
        if access_token:
            new_releases = search_new_releases_by_genre(access_token, GENRE_LIST)
            display_releases(new_releases)
# Out:
# Searching for new releases in genre: 'rock'...
#
# Searching for new releases in genre: 'alt-rock'...
#
# Searching for new releases in genre: 'indie'...
#
# Searching for new releases in genre: 'punk'...
#
# Searching for new releases in genre: 'hardcore'...
#
# Searching for new releases in genre: 'metal'...
#
# Searching for new releases in genre: 'death-metal'...
#
# Searching for new releases in genre: 'black-metal'...
#
# Searching for new releases in genre: 'deathcore'...
#
# Searching for new releases in genre: 'hip-hop'...
#    > Found 1 new unique releases.
#
# Searching for new releases in genre: 'trap'...
#
# Searching for new releases in genre: 'rap'...
#
# Searching for new releases in genre: 'pop'...
#
# Searching for new releases in genre: 'synth-pop'...
#
# Searching for new releases in genre: 'electronic'...
#
# Searching for new releases in genre: 'techno'...
#    > Found 1 new unique releases.
#
# Searching for new releases in genre: 'house'...
#
# Searching for new releases in genre: 'ambient'...
#
# Searching for new releases in genre: 'jazz'...
#    > Found 2 new unique releases.
#
# Searching for new releases in genre: 'soul'...
#
# Searching for new releases in genre: 'funk'...
#
# Searching for new releases in genre: 'blues'...
#    > Found 1 new unique releases.
#
# Searching for new releases in genre: 'classical'...
#
# Searching for new releases in genre: 'folk'...
#
# Searching for new releases in genre: 'country'...
#
# Searching for new releases in genre: 'metalcore'...
#
#
# --- 🎸 A More Comprehensive List of New Releases ---
#
# 1. [Album] Genre_vore - Midnight Jazz Haunts (Echoes in the Velvet Dark)
#    Released: 2025-09-20
#    Listen here: https://open.spotify.com/album/1vel9EZPXtEYBoYqx8yMTW
#
# 2. [Album] Genre_vore - Haunted Hilarity (Jazz Jumps & Jests)
#    Released: 2025-09-20
#    Listen here: https://open.spotify.com/album/4hxAulqRz06IYURXrpxKve
#
# 3. [Album] Sirmadsen - SirMadsen's Genre Blending (Classical Techno)
#    Released: 2025-09-18
#    Listen here: https://open.spotify.com/album/5apc2NdmePf3eEWLq7hP9D
#
# 4. [Album] DJ Lil Bones - GENRE LESSONS: HIP-HOP (ALTERNATE VERSIONS) [Alternate Version]
#    Released: 2025-09-14
#    Listen here: https://open.spotify.com/album/6ya2D2G9ynMCXZAKio3bGQ
#
# 5. [Single] Daniel Durvin - Chicken fight Blues
#    Released: 2025-09-13
#    Listen here: https://open.spotify.com/album/2rAgbZtOSjcbpSJBz9IIPl
#
# --- Total Unique Releases Found: 5 ---

# %%
import requests
import base64
import time
from datetime import datetime, timedelta, timezone

# --- Your Spotify API Credentials ---
CLIENT_ID = "f7a1820968e54174840f1284ed125c56"
CLIENT_SECRET = "f5f4d35c3aa94200a62b0b9a9b524dd5"
# ------------------------------------

# --- Configuration ---
TARGET_USER_ID = "spotify"
# -----------------------------


def get_spotify_token(client_id, client_secret):
    """Gets an access token from the Spotify API."""
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode('utf-8')).decode('utf-8')
    headers = {'Authorization': f'Basic {auth_header}'}
    data = {'grant_type': 'client_credentials'}
    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Error getting token: {response.status_code} - {response.text}")
        return None

def get_all_user_playlists(token, user_id):
    """Fetches all public playlists from a specific user's profile."""
    headers = {'Authorization': f'Bearer {token}'}
    all_playlists = []
    # This is the correct endpoint for getting a user's playlists
    next_url = f'https://api.spotify.com/v1/users/{user_id}/playlists?limit=50'

    print(f"Fetching all public playlists from user '{user_id}'... This will take a moment.")

    while next_url:
        response = requests.get(next_url, headers=headers)
        if response.status_code != 200:
            print(f"   > Error fetching playlist data: {response.status_code} - {response.text}")
            break

        data = response.json()
        all_playlists.extend(data.get('items', []))
        next_url = data.get('next')
        time.sleep(0.1)

    return all_playlists

def display_profile_playlists(playlists):
    """Displays the fetched playlists in a readable format."""
    if not playlists:
        print("Could not find any playlists for this user.")
        return

    print(f"\n--- 🎧 Found {len(playlists)} Playlists on Spotify's Profile ---")

    for i, playlist in enumerate(playlists, 1):
        name = playlist['name']
        playlist_id = playlist['id']
        # Truncate long descriptions for cleaner output
        description = (playlist['description'] or "No description.").replace('\n', ' ').strip()
        if len(description) > 100:
            description = description[:97] + "..."

        print(f"\n{i}. {name}")
        print(f"   ID: {playlist_id}")
        print(f"   Description: {description}")


if __name__ == "__main__":
    access_token = get_spotify_token(CLIENT_ID, CLIENT_SECRET)
    if access_token:
        spotify_playlists = get_all_user_playlists(access_token, TARGET_USER_ID)
        display_profile_playlists(spotify_playlists)
# Out:
# Fetching all public playlists from user 'spotify'... This will take a moment.
#
# --- 🎧 Found 346 Playlists on Spotify's Profile ---
#
# 1. Classic Honky Tonk
#    ID: 0NfjMqrzcGKVsbYZmhf4Md
#    Description: All songs about drinking, cheating, heartaches and everything else going on in a classic honky tonk.
#
# 2. Nicholas Sparks | Songs from the Soundtracks
#    ID: 1scnlLVq91NGtsA9sh0hfw
#    Description: Go behind the scenes of the <a href="http://www.twobytwomusic.com">Two By Two</a> book soundtrack...
#
# 3. 1960s Nostalgia
#    ID: 2NFOUmp2wyR5CrXtKDkUkB
#    Description: Those were the days, this was the music...
#
# 4. Breakup Blues
#    ID: 1o2bTwofazfzElA5mXGf2t
#    Description: From denial and pleading to anger and acceptance, this genre-blending playlist will carry you thr...
#
# 5. I Hate My Job.
#    ID: 6cdV0hVW2suJaMOxzwE46S
#    Description: We've all been there. This playlist can help. Just don't let your boss catch you listening....
#
# 6. Instrumental Rock
#    ID: 2uhsnHgI4F2eFyvoMHY0GR
#    Description: Rock your workday lyric free with classic rock favorites, meditative heavy metal, and art rock wo...
#
# 7. Avant Folk
#    ID: 2uVP1agvV5rba3MqLQ0pzy
#    Description: Despite their nomenclature defying eclecticism, these folk inspired artists share a collective pe...
#
# 8. The Perfect Crafternoon
#    ID: 0BbcjurkvWrkWxKKLzcqIP
#    Description: Soundtrack a perfect crafternoon spent scrapbooking, knitting, or working on projects with friends.
#
# 9. Power Ballads
#    ID: 44XJR1i3Vl2B3acOEYwinE
#    Description: You know you love them.... Get ready to sing like no one is listening to scores of timeless pop a...
#
# 10. Energy + Positivity
#    ID: 2YeGkAUQhmO8TCjSMbFYWf
#    Description: Honor your body, fuel your mind. Love Life. Live Yoga.
#
# 11. Namaste
#    ID: 0op6xwVK9pVhcxozSQPEsJ
#    Description: Take some time out of your day to recharge your mind.
#
# 12. Rustic Romance Wedding
#    ID: 2Ph68VcwRfqRdnrKhY3oPS
#    Description: A charming musical touch to the most significant moment in your life.
#
# 13. Word of Mouth
#    ID: 2VxQy0Q22k1gP542tzaMCN
#    Description: Explore the evolution of eternal folk songs through some of their essential adaptations – from fi...
#
# 14. Indie Strings
#    ID: 0sDO43KAaJUWIYassTKWYf
#    Description: Songs with some serious violin and cello action.
#
# 15. Vinyasa Flow
#    ID: 2B64RN7KJte5x6iXgg02tv
#    Description: Focus your gaze and get into the dynamic flow of this engaging, eclectic mix.
#
# 16. Acoustic Commute
#    ID: 3OUguxmuL5x24sMAw4qPku
#    Description: Turn your commute into a perfect, peaceful drive...
#
# 17. Summertime Vibes
#    ID: 5v2J2noHVxPWgSrOw6lZsp
#    Description: Salt in the air... Sand in my hair... Rooftop sunsets... Celebrate a perfect summer day with hour...
#
# 18. More Banjo!
#    ID: 1W2XJETQjFYdzT4GuhBHmS
#    Description: This playlist is perfect for when you've got a fever... and the only prescription is more banjo!
#
# 19. Chill as Folk
#    ID: 43rSnXFDoctqiZxvEqH14P
#    Description: Your go-to collection for just hanging out and doing nothing... or whatever.
#
# 20. The New Bohemian
#    ID: 1IKDP8o4UvpfLh0SJX2e1b
#    Description: Free-spirited, eclectic, and decadent lyrics mix with folksy, indie, and slightly psychedelic aco...
#
# 21. Sweetgrass
#    ID: 44Ht3IACEyKqiLBZupIhIk
#    Description: Sweet and slow, soft and soothing... a collection of beautiful bluegrass vocals.
#
# 22. Sweet Winter Songs
#    ID: 62Tpw0jhT8kxF3KPbGciTk
#    Description: As the snow falls outside, cozy up and relax with this collection of soothing acoustic tracks.
#
# 23. Disco Beats
#    ID: 0pHFNRP8qkYhal0q0Irp6D
#    Description: You should be dancing, yeah. (This ain't your typical disco either...)
#
# 24. Rock & Roots
#    ID: 7pD7pMFxcq8agMXqLQCggM
#    Description: New takes on old sounds. These tracks talk back to their roots in the folk, blues, soul, country,...
#
# 25. Interstate Drive Songs
#    ID: 0XDRWlx2B1C1OXlaLlld8t
#    Description: Coast along to the best of the alt rock era.
#
# 26. Low Key Revelry
#    ID: 67uEKAhAdvMJvumeC8ZgjB
#    Description: Unwind and enjoy the evening.
#
# 27. Best of 2016: Folk & Americana
#    ID: 0fmNiEOXSfBfurQwf4gG5L
#    Description: Take a look back on some of the year's top tracks in roots music. We'll be adding more of your fa...
#
# 28. Best of 2016:  Hot Country
#    ID: 7g3zHOim2XylTlM7Oittr8
#    Description: Enjoy the top streamed country songs of 2016 right here! Cover: Dan + Shay
#
# 29. Guest List: Orb
#    ID: 2O0Nf9Mi5tM17PM7Ns6Fgu
#    Description: Orb's official Spotify Gaming playlist! Full of high BPM, kick-ass melodies and euphoria.
#
# 30. Artists Den + Spotify
#    ID: 1HdxEroWca3L8JR3lvnolH
#    Description: Visit <a href="http://artistsden.com/zacbrownband">ArtistsDen.com</a> to win tickets to see Zac B...
#
# 31. Women in Music | Stories & Songs
#    ID: 1zriHsmiRJmTThtQk8UWPk
#    Description: Listen to a collection of inspiring women in music as they share the stories of their music icons...
#
# 32. BRILLIANTMINDS2016
#    ID: 57clV3IPw1TXSWdzzDVDwp
#    Description: Relive your favourite artist moments from the Brilliant Minds conference during <a href="http://s...
#
# 33. Incoming
#    ID: 79sVcfxVNazjyK2iBY9l3q
#    Description: Rolling Stone contributing editor Joe Levy presents Incoming, a new panel discussion show about w...
#
# 34. AMY
#    ID: 3QAT1vJA7CAIHIRP9Gkyqj
#    Description: An inside look into the new Amy Winehouse biopic, featuring exclusive interview clips and top pic...
#
# 35. Follow Your Bliss
#    ID: 2wqwH7uKckoLe7UVTx1RfO
#    Description: Coast through the good life with these folksy and blissed out tracks.
#
# 36. Rest & Relaxation
#    ID: 1uIp2WHCf6ODHxHRPmjWG5
#    Description: No description.
#
# 37. One Perfect Day
#    ID: 6jUFiT3D8f4Rt9n6UnC1aB
#    Description: No description.
#
# 38. Get Happy!
#    ID: 4Buj61XKuhfVLsW8rPX8YQ
#    Description: 100+ of the happiest songs of all time. Come on, Get Happy!
#
# 39. Lazy Afternoon
#    ID: 6QAwHYtCdTdrgX6wh1iE9H
#    Description: Lounge around without a care in the world...
#
# 40. The Bridge
#    ID: 4qq3MCSLrDgYx7RfJBDvij
#    Description: From then to now, these songs will forever be classics.
#
# 41. Spring Garden
#    ID: 6YMK6nqc1jS11fGraCU1o2
#    Description: Sleep, study, or simply still your mind with the soothing sounds of spring.
#
# 42. Nightly Meditations
#    ID: 4MLFX9OXy9ncfBlTfei9Ok
#    Description: &quot;Sleep is the best meditation.&quot; -Dalai Lama
#
# 43. (Descent) A Beginning
#    ID: 71WgbCkbVXGzAltJTAT6lD
#    Description: Slip into the world of Brian Eno...
#
# 44. Covered in Country
#    ID: 0jJQDST7bzwAYlN19tFLXw
#    Description: No description.
#
# 45. Traffic Jams
#    ID: 0mY9BQvlpraYLzg9BfKuVa
#    Description: Stuck in stop and go? This should help.
#
# 46. #JazzAppreciationMonth
#    ID: 2nb7lCySvvf7PNxHUD5oun
#    Description: In honor of JAM, we're collecting your favorite jazz tracks! Share yours at #SpotifyJAM
#
# 47. Motivation Montage
#    ID: 2f4rXblveCedKdU2adFgC8
#    Description: Live large, run hard. Score your workout with some epic action movie soundtracks.
#
# 48. Sugar & Spice
#    ID: 7MsOqrEv1TxiHPDiYlWVLx
#    Description: ...and everything nice. Enjoy your dinner to the sounds of classic jazz vocals.
#
# 49. Soul Soothers
#    ID: 3TymQFosH9UgfP5jV5mPEe
#    Description: Smooth soulful tracks to ease your troubled mind...
#
# 50. Winding Roads
#    ID: 1JuraqRjLX4CmhyvvuXiPF
#    Description: Take the back roads...
#
# 51. Carpool Karaoke
#    ID: 0NaXa68Xyo4wmMiun5Lqgm
#    Description: Turn your commute into a karaoke party. Stay tuned for the next edition. This time: Rock Ballads.
#
# 52. Songbirds
#    ID: 5JXV7ioEqB9ZA1b1RjSLVg
#    Description: Wake up to Songbirds, a mix of melody-driven indie, folk, and Americana.
#
# 53. Into the Woods
#    ID: 3fqSEmStIKS8s3mCCRQFid
#    Description: Enjoy a sun-dappled stroll to these folksy, mid-tempo gems.
#
# 54. Bluegrass Byways
#    ID: 2EjRsHG8m4bGCrhCoJ1ykn
#    Description: Drive happy with these upbeat bluegrass tracks.
#
# 55. The Scenic Route
#    ID: 6pn7MZpvAxlKPzspzMR6T6
#    Description: Take in the view and get lost in total backroads bliss with this mellow indie folk...
#
# 56. We Dem Girlz
#    ID: 3g2dsbLbtpOz0Gpo4W50QK
#    Description: Because we love our Hip Hop... Dance away!
#
# 57. 1960
#    ID: 2PE0DbAlT8ZFiiYaCsCm4Q
#    Description: No description.
#
# 58. 1961
#    ID: 7EhO7YjjFdrNRtTHcRrnnQ
#    Description: No description.
#
# 59. 1962
#    ID: 7GSt7smvMMAiOFmPJ17jEf
#    Description: No description.
#
# 60. 1963
#    ID: 6c1DPPuq4eNKcS2usgij9m
#    Description: No description.
#
# 61. 1964
#    ID: 2XFhZrcFAFFvBLjRQrw9wI
#    Description: No description.
#
# 62. 1965
#    ID: 48GGszBLm7kS5D1xJuMnxD
#    Description: No description.
#
# 63. 1966
#    ID: 41YL3HcXd3zTXa1rMZY5uR
#    Description: No description.
#
# 64. 1967
#    ID: 3nT5EK7WTRbRZ5vtWg5irD
#    Description: No description.
#
# 65. 1968
#    ID: 0sbkEFgqbA3Jjot2lbqsyx
#    Description: No description.
#
# 66. 1969
#    ID: 1xZ87c95aRIeyvqVoKCtdM
#    Description: No description.
#
# 67. 1970
#    ID: 09D0CKBRWkBBoPn46V6YTO
#    Description: No description.
#
# 68. 1971
#    ID: 5xAfItDaeAViBRNdSuQ7ZG
#    Description: No description.
#
# 69. 1972
#    ID: 1DcArrb34m9SS3o8O2dATX
#    Description: No description.
#
# 70. 1973
#    ID: 5WUFWhGRVpi4ED9QpK2hOF
#    Description: No description.
#
# 71. 1974
#    ID: 78UTV8Gw5bHpyWc65qR4Px
#    Description: No description.
#
# 72. 1975
#    ID: 67FrRIrS2v0WAs8yE2JTUM
#    Description: No description.
#
# 73. 1976
#    ID: 3axv4DMbWHWf7uxOPB1I7K
#    Description: No description.
#
# 74. 1977
#    ID: 2cIkPMesqdx5VV6IAvX9bE
#    Description: No description.
#
# 75. 1978
#    ID: 05dTMGk8MjnpQg3bKuoXcc
#    Description: No description.
#
# 76. 1979
#    ID: 2xtEcvpPTus59Ppa0fv3xP
#    Description: No description.
#
# 77. 1980
#    ID: 4j0G7LOHRpKYDDXa8lxUik
#    Description: No description.
#
# 78. 1981
#    ID: 5Co3nToduGTXXF1ra9gXB3
#    Description: No description.
#
# 79. 1982
#    ID: 722UH6DU3oigTYKBnfBZSy
#    Description: No description.
#
# 80. 1983
#    ID: 2wHQqJDXcWgQ4GLdVCfb8G
#    Description: No description.
#
# 81. 1984
#    ID: 0FXAO6yBxrfz5PTOEuvq67
#    Description: No description.
#
# 82. 1985
#    ID: 5p5jgESe4r75R70Rzvqpcy
#    Description: No description.
#
# 83. 1986
#    ID: 3GM3OMvut5VuRht0dr8GJX
#    Description: No description.
#
# 84. 1987
#    ID: 6sKz6mI28U6Dcj7a8WpRnQ
#    Description: No description.
#
# 85. 1989
#    ID: 1ASJaLRG6NhOpwc8vGYceZ
#    Description: No description.
#
# 86. 1990
#    ID: 0COE1X7FirWRdfOgls1JJV
#    Description: No description.
#
# 87. 1991
#    ID: 6ATJMRUakF2bhZcPBYjnD5
#    Description: No description.
#
# 88. 1992
#    ID: 62NfPhRvacdmSAsNghaRs5
#    Description: No description.
#
# 89. 1993
#    ID: 33sPgLhtkMgQLWMgdHRQma
#    Description: No description.
#
# 90. 1994
#    ID: 27hnSuEcFg6wr5C5t3J5eL
#    Description: No description.
#
# 91. 1996
#    ID: 1FDK3hDHMSyzjC1IpdIOU3
#    Description: No description.
#
# 92. 1997
#    ID: 4nftZhTZDARHbC2oX5l2Vw
#    Description: No description.
#
# 93. 1999
#    ID: 1WkrD0MvdN3BcLa4DXBRCQ
#    Description: No description.
#
# 94. 2000
#    ID: 0JvFNpF6sn3LeV5LXbbSxv
#    Description: No description.
#
# 95. 2001
#    ID: 5TUU1rXz87AipJYg92AXFg
#    Description: No description.
#
# 96. 2002
#    ID: 665gwFk3RaSHbgiimtgok0
#    Description: No description.
#
# 97. 2003
#    ID: 2I7h7Mj5bGlqhI4PyupTPF
#    Description: No description.
#
# 98. 2004
#    ID: 1XbPuTCA2KsqAOn9PJploZ
#    Description: No description.
#
# 99. 2006
#    ID: 1Gn0PYtF7VmfuZD0Gb91fN
#    Description: No description.
#
# 100. 2007
#    ID: 0KIKHBXChX4m2MVm8qQk6N
#    Description: No description.
#
# 101. 2008
#    ID: 3jibtPWLDXBK0OCJN6Ztsf
#    Description: No description.
#
# 102. 2009
#    ID: 1fLy5EE5473UueC82LvQub
#    Description: No description.
#
# 103. 2010
#    ID: 2eCpwX876ZuWtIsZweYMnr
#    Description: No description.
#
# 104. 2011
#    ID: 0BXZJ6BiA151CzaMcTKPMN
#    Description: No description.
#
# 105. 2012
#    ID: 7z2Wo5a21ENb24YGcEdoTE
#    Description: No description.
#
# 106. Dear Mama
#    ID: 3D8eZBmcXjAjFzUjYtrl6f
#    Description: To the best mother in the world.
#
# 107. Top 100 tracks of 2014 - Sweden
#    ID: 23sHdrU9wnUTqYjHZQ101O
#    Description: Sweden couldn&#x27;t get enough of these tracks in 2014! See how the rest of the world listened a...
#
# 108. Joe Cocker
#    ID: 2rdMSQHM9YryNLPnEbQ7g6
#    Description: A collection to remember and honor the music and life of Joe Cocker.
#
# 109. Happy Birthday Cheryl!
#    ID: 7qLIVhpCFAiX1Teqf3L6Y4
#    Description: No description.
#
# 110. June 2
#    ID: 5PzDJIsyNnFxgu0t6Lf41G
#    Description: No description.
#
# 111. May 20
#    ID: 7IwNlM5pdX8XWPyhMRhq64
#    Description: No description.
#
# 112. Grazia Daily: Summer 2013
#    ID: 2UwTnYkh7zZjMY6NEQdP95
#    Description: No description.
#
# 113. LSP
#    ID: 6cSrBkF4TPHetlU033IopA
#    Description: No description.
#
# 114. Vogue Travel: The Sound of the Upper East Side
#    ID: 61T3llVc7dJDCZf1SR72c0
#    Description: No description.
#
# 115. POST
#    ID: 1OhJNFdK6FhLToiHmx7abI
#    Description: No description.
#
# 116. Disclosure's Spotify Playlist
#    ID: 1npVCZGxmhbfhAyeDEqhwA
#    Description: No description.
#
# 117. The Roots of... Mumford & Sons
#    ID: 78Afk1ZdGIAwEG8s3hq49D
#    Description: No description.
#
# 118. June 10
#    ID: 1pARmsw0z4yebhBtZKxAU0
#    Description: No description.
#
# 119. HAIM
#    ID: 5hINCaYWvVwzzLmhh4y11x
#    Description: No description.
#
# 120. 101_FTB
#    ID: 6llXb59kkj2STIMBcDobJT
#    Description: No description.
#
# 121. Grazia Daily: The Best of Primavera
#    ID: 2ns4wV7T6X3vlCnzxYwagu
#    Description: No description.
#
# 122. braids
#    ID: 4fFfXVLYv59XIfPdUvMqKC
#    Description: No description.
#
# 123. XFM JUNE 26
#    ID: 31agQ1yW51tGsDIFZbAZMl
#    Description: No description.
#
# 124. The Beach Boys: The Real Best Of...
#    ID: 1omLAKnMAhhkMSe2IGisUZ
#    Description: No description.
#
# 125. boys cast
#    ID: 0kfqBZx9obUKiLVDwTqGly
#    Description: No description.
#
# 126. Happy Birthday George!
#    ID: 2G5Wlqt6clkHH2KFK2LS5Q
#    Description: No description.
#
# 127. Remembering 2Pac
#    ID: 6vpXSVefNo73POjhwyiWmu
#    Description: No description.
#
# 128. The Hot Sounds of 1926
#    ID: 3rMnCpY0WEROlje2b8Bjdn
#    Description: No description.
#
# 129. Happy Birthday Kanye!
#    ID: 45Cyxm3R3Gpn2upYrjcPbc
#    Description: No description.
#
# 130. Mollie King
#    ID: 0dVRyMERU2g9M4tWEfaD5B
#    Description: No description.
#
# 131. Happy Birthday Sir Tom!
#    ID: 5Ir6gs0eXKyPj3Qin8uEun
#    Description: No description.
#
# 132. Happy Birthday Prince!
#    ID: 44uPoVqT6tOn5AphWVnSvu
#    Description: No description.
#
# 133. Happy Birthday Joe Cocker
#    ID: 66uSq0mmMKat8vPRxsbmhp
#    Description: No description.
#
# 134. Happy Birthday Mollie!
#    ID: 4njfFyb4EgzewhH9kTQuwN
#    Description: No description.
#
# 135. Congratulations, Sofia and Daniel
#    ID: 2vfyCK7WsXnVeItNwuiFFR
#    Description: No description.
#
# 136. Welcome Baby Kimye!
#    ID: 5zpAWvvDe0Q8TXjrgInIke
#    Description: No description.
#
# 137. The Roots of... Vampire Weekend
#    ID: 52FOMIrumGaNXnwKfrlAVf
#    Description: No description.
#
# 138. PF
#    ID: 6kDXxWpyGJ2f7nQWQwOMBA
#    Description: No description.
#
# 139. Happy Birthday Nicole!
#    ID: 1dB0DjEsx9Gy0VG7Hmyc7Q
#    Description: No description.
#
# 140. JIRMP
#    ID: 6r0dNjQD0WUHKs1gpMvpLk
#    Description: No description.
#
# 141. Happy Birthday Sir Paul!
#    ID: 3npIV1kNBTG2NHwBfv4t5H
#    Description: No description.
#
# 142. Happy Birthday, Lionel
#    ID: 13WGZTkVyBhWCD2z7wSwe7
#    Description: No description.
#
# 143. Global Music Day
#    ID: 2EsohEQHsGn1LWNgOxnuoI
#    Description: No description.
#
# 144. Dub Zone
#    ID: 0qNxhUDMiSLrSdTCYD87qn
#    Description: No description.
#
# 145. Hats The Way I Like It: Ascot 2013
#    ID: 2hirOuzhv3EK3AgEV2nKZn
#    Description: No description.
#
# 146. Pink Floyd: Start Here
#    ID: 4SJ51ZOUgnrv5GjY1GCZAL
#    Description: No description.
#
# 147. RIP James Gandolfini
#    ID: 3l6cfhKgkSNxYydKiD9o4G
#    Description: No description.
#
# 148. Mountain Session
#    ID: 6LY1QKuuZv6rtPKsHJSsnF
#    Description: Want to go from 360s to 1080s or just get some extra heights in your airs. Then this list is for ...
#
# 149. Spotify Sessions
#    ID: 0tkdz9yYluhlxVE9BuJOPm
#    Description: A collection of live, exclusive performances from the most exciting artists in the world.
#
# 150. Great Love Ballads
#    ID: 1YGlW3ovCv9Vek4CPnV0mZ
#    Description: There's no greater feeling than love, which means that it requires great music. Here is a collect...
#
# 151. Only Lovers Left Alive - Playlist by Jim Jarmusch and Carter Logan of SQÜRL
#    ID: 0YX4v2yeHtc1Dz43CYfZub
#    Description: ONLY LOVERS LEFT ALIVE will be in cinemas from 21st February. The soundtrack will be available fr...
#
# 152. CAZZETTE – Eject pt. I
#    ID: 1kPmmFOfrsEk7KzW46uo8m
#    Description: No description.
#
# 153. US Exclusives
#    ID: 3kNL4k3rmfGRfx577lL715
#    Description: No description.
#
# 154. Nelson Mandela Tribute
#    ID: 7iUOaMP7iKI22rBNflBwjX
#    Description: No description.
#
# 155. Spotify Global Discoveries
#    ID: 0aArwHugPhiiuaL8KxyVXQ
#    Description: No description.
#
# 156. Spotify Global Hits
#    ID: 4nInziu6O7lNV0ucn8w7YV
#    Description: No description.
#
# 157. New Singles on Spotify
#    ID: 5JOn3LSfpbCrOQ7azB4S6C
#    Description: The latest singles on Spotify all in one playlist. Updated weekly.
#
# 158. Top Dads on Spotify
#    ID: 5lMXuhAFbG0xiAw0XiYKAP
#    Description: No description.
#
# 159. Top Misquoted Song Lyrics
#    ID: 4nGMejqlEJh82huRHZ19cE
#    Description: No description.
#
# 160. Keep On Pushing: A Labour Playlist
#    ID: 6WHZXvb7hEN5w9VMFWPm1x
#    Description: No description.
#
# 161. Top Tracks in Kids
#    ID: 5BQyCxfPfCno0PuTqkZUgb
#    Description: No description.
#
# 162. Top Tracks in Popculture
#    ID: 6dvI9YLz5JyXhoUo0eQJze
#    Description: No description.
#
# 163. Top Tracks in Travel
#    ID: 2Hg4Q2t6mD8PITWKAQCMFD
#    Description: No description.
#
# 164. Top Tracks in Workout
#    ID: 7s0efM9c1ZS427tw2B6wEF
#    Description: No description.
#
# 165. Spotify House Thursday
#    ID: 6NjugpbMNtXAtbv3NIbb3j
#    Description: The Spotify House 2015 Thursday lineup.
#
# 166. Walter - Dangerous
#    ID: 53yqWl4VM0iD34tl27ABhY
#    Description: No description.
#
# 167. Skyler - Strong
#    ID: 08ySLuUm0jMf7lJmFwqRMu
#    Description: No description.
#
# 168. Hank - Gutsy
#    ID: 2nRUp0P50ClCxPibGSfFcL
#    Description: No description.
#
# 169. Jesse - Street Smart
#    ID: 10zBfLMB5ty2Pec5LYRcgI
#    Description: No description.
#
# 170. Marie - Sassy
#    ID: 423y0vzm6cfn0Q1o3JBUDR
#    Description: No description.
#
# 171. Walt Jr. - Innocent
#    ID: 7dRuhLsXe96SgjYtPvMEcL
#    Description: No description.
#
# 172. Metallica: The Early Years
#    ID: 056jpfChuMP5D1NMMaDXRR
#    Description: Companion playlist for the Metallica documentaries.
#
# 173. New Wave Of British Heavy Metal
#    ID: 7yza99mVQaqnk4Hqs4T3kq
#    Description: Companion playlist for the Metallica documentaries.
#
# 174. Year in Metal 2014
#    ID: 7buHbubC96caOTOSQQJ4pl
#    Description: Another great metal year is coming to a close. Explore this year's highlights in metal with this ...
#
# 175. We Love Elmo!
#    ID: 2KSySxa7iudjK0IsgFxuaW
#    Description: It's Elmo's time to shine!
#
# 176. Lost the Game? Drown Your Sorrows
#    ID: 5sFZ3M4gXeYScR9VJTyBh2
#    Description: You can't win 'em all. Drown your sorrows with a cold brew and this drinking playlist.
#
# 177. Austin Pops
#    ID: 15wD5DzfOIRx7QnJKDLtav
#    Description: Your guide to what's hot in Austin, TX during South By Southwest 2017. Cover: <a href="spotify:ar...
#
# 178. Austin After Dark
#    ID: 50l7KMPuO1jMnpofYHCwV1
#    Description: The evening is here in Austin. Time for some music to get it started all over again!
#
# 179. Punkcake
#    ID: 2Ky26QAfAYo2Zdlo8MqcdH
#    Description: Listen the best of punk pop during your breakfast.
#
# 180. The Life Eclectic
#    ID: 35HteeTTB5NE0hsliZ77H1
#    Description: Yours is no ordinary life. Listen outside the lines.
#
# 181. Evening Serenades
#    ID: 2zlFpwRI7aroWy0ecv6O34
#    Description: Wind down for the evening with your special someone and this soothing selection of serenades.
#
# 182. Flex & Flow
#    ID: 2idQpnxeioGlOsW66uaQ3U
#    Description: This eclectic, electric-leaning collection is perfect for focusing on your flow and extending you...
#
# 183. Workday – Zen
#    ID: 1oDFttzXiLUJLjMyulUugY
#    Description: Achieve optimal workday zen with this relaxed, meditative mix.
#
# 184. Keep it Low Key
#    ID: 26AgqJwDHB7p2SKJFHrtte
#    Description: ... and don't take yourself too seriously.
#
# 185. Classical Café
#    ID: 0Tn4EK4iKI58XnvWHuMMm0
#    Description: Power through your to do list with an affogato and a refreshing mix of chilled classical.
#
# 186. The Grove
#    ID: 5H22bACwDGRsIQQyE9oy3I
#    Description: Relax in the shade and uncover the best new underground folk and rising Americana.
#
# 187. Fresh Jazz | The New Vanguard
#    ID: 1Htq6RhM8B9MgMXdwqgPxW
#    Description: Break out of your routine with trios of tracks from some of the brightest new stars in Jazz.
#
# 188. Get Lifted
#    ID: 6jbGdICAmvGjlURC1gcgRe
#    Description: Jazzy soul and rnb ballads to wake you up and lift your mood...
#
# 189. Jazz on the Rocks
#    ID: 6juf9A1KL8naPZFa2YngsM
#    Description: Score your cocktail hour with eclectic jazz covers - from Drake to Radiohead.
#
# 190. #SundayFunday
#    ID: 5cdRxEiQmawJaraYYEF7Di
#    Description: Infectiously happy hits from years past blended with the best of today's chart toppers.
#
# 191. #FlashbackFriday
#    ID: 2dWfCGZguakRQagX7wM6Mi
#    Description: Stay tuned for a fresh mix of flashback hits! This week, party like it's 1999!
#
# 192. Amped up.
#    ID: 0kVaFpvoi0O4IbyJyEZckU
#    Description: Psych yourself up for whatever you've got going...
#
# 193. The New Standards
#    ID: 5ahhg3aywppGeJs8tXvZOo
#    Description: Fresh takes on all of your favorite standards.
#
# 194. Up & Out
#    ID: 2udwObkzQEPQWbUi95SzGM
#    Description: Escalating folk and chamber pop to pump up your day.
#
# 195. Take it Easy
#    ID: 3vnx7BaCl3YmHrg3WGLedp
#    Description: Harmonicas &amp; slide guitars for the win. Chill out with some laid back roots &amp; Americana.
#
# 196. Britfolk
#    ID: 5XyoROE7WrTHtvcwFrhzO1
#    Description: The best in folk and singer songwriter from the UK and Ireland.
#
# 197. Morning Rituals
#    ID: 7iJKTAmd5aP1opVYLB3XJ4
#    Description: Push play on a slowly building mix of indie folk faves as you roll out of bed and get your coffee...
#
# 198. #MakeitHappen
#    ID: 5sty33UvgJZzeyfocoOaUV
#    Description: Get the most out of your day and #makeithappen.
#
# 199. Singing in the Shower...
#    ID: 5LtwydYUv9Um4D2toY3Wzh
#    Description: ...dancing in the mirror.
#
# 200. Vintage Blues Folk
#    ID: 6zcjhNUkQ6taQK9hxhweCj
#    Description: Deep, dark, gritty, vintage sounds from the best in indie blues folk.
#
# 201. Indie Ballads
#    ID: 0aXP5u51kHZiKvxkUPq0IL
#    Description: Score your day with some signature indie ballads.
#
# 202. Barista Blend
#    ID: 25zEHXJzEQZU1eyF6eqEzD
#    Description: A rich, mellow blend of hits to see you through your most productive days and cozy nights.
#
# 203. Bring Back the 2000s
#    ID: 5baU2nNxC8ag8XzlHNsANg
#    Description: All your favorite hits from the decade you love most!
#
# 204. World Folk
#    ID: 0ByLkBLDx1AS5yXJuBTyCd
#    Description: Travel the world through sound – with indie and traditional folk and acoustic from across the globe.
#
# 205. Indie One Stop
#    ID: 6OeIIMFsdtsL9VUyL6PDvX
#    Description: All the hottest current Indie music you need....in one stop.
#
# 206. Beat Down Your Morning
#    ID: 4qstWgP2KMRSiTY3a1fF2R
#    Description: Get your morning on the ropes with some ANGRY ROCK!
#
# 207. Wicked Wives Wine Party
#    ID: 2EcSH9oZNzBmGDNqoTdvBJ
#    Description: We married women only seem to have about four taste buds left: one for vodka, one for wine, one f...
#
# 208. #Hotmess
#    ID: 2Rah43YvyO765e4gACIDef
#    Description: Wake up in your makeup? Rock it.
#
# 209. Ultimate Live Jams
#    ID: 5bjjHyKeiGnYdupfr3UUCW
#    Description: Ten hours of ultimate jams —all long, all live.
#
# 210. Stories for your Inner Child
#    ID: 5TQKebIP2y3YGxoklr72aV
#    Description: Fairy tales and children's classics sure to satisfy your inner child...
#
# 211. Beyond the Music
#    ID: 01WIu4Rst0xeZnTunWxUL7
#    Description: Go beyond the music with audio documentaries, rare interviews, and behind the scenes biographies ...
#
# 212. FriendsGiving
#    ID: 7a80QjnKAMnZu5Lx50INeh
#    Description: Enjoy the company of friends alongside some folksy acoustics perfect for an autumn dinner party.
#
# 213. Bellini's Opera
#    ID: 1M2abQkxCwrLjzLGgKWnDP
#    Description: Lend some gravitas to the moment with the complete works of Vincenzo Bellini, featuring acclaimed...
#
# 214. Red, White, & Blue
#    ID: 3kt5kS8Xqjfh8olOS24HX4
#    Description: Get your sparklers out for this patriotic blend of folk, pop, and Americana.
#
# 215. 50 Songs for Snow
#    ID: 4sEKPcBYLcW3woDviiaigj
#    Description: Give in to the season, with the ultimate collection of classic snow songs.
#
# 216. It's a Boy!
#    ID: 3KP0xIq8NrTP7BV2YhpHT5
#    Description: Celebrate your baby boy and spread the good news!
#
# 217. It's a Girl!
#    ID: 52rJQYDn9Q5dufvGPqqzgf
#    Description: Celebrate your baby girl and spread the good news!
#
# 218. Graduation
#    ID: 5pxi1UkDk0BbUPDTPjmi4v
#    Description: Here's to cherishing lifelong friends, remembering the good times, and celebrating the end of an ...
#
# 219. Music Happens Here: The Music
#    ID: 4se8FxjaBGTHCTXIPoJlc0
#    Description: Music from the podcast Music Happens Here. This episode focuses on the most iconic songs of Los A...
#
# 220. Best of 2016: Ultimate Indie
#    ID: 1517hhPIVwA9EN41krpZo3
#    Description: Check out the top streamed indie tracks of 2016!
#
# 221. The 2016 AMAs
#    ID: 0tdTsuJmnf6cRE22DMcgIq
#    Description: The American Music Awards is the world’s biggest fan-voted award show. This year, hosts Gigi Hadi...
#
# 222. Classic Soul With Seth Rogen
#    ID: 6GZ9F4MZpPdHJEwhq3kHKG
#    Description: Listen to all of Seth's favorite classic soul tracks right here. And be sure to check out his cha...
#
# 223. Top Gaming Tracks: One Year Together
#    ID: 2FmMinHNFfX3Apt34AwEqc
#    Description: Celebrate one year of Spotify and PlayStation with the biggest tracks.
#
# 224. Moving Castle Monthly
#    ID: 0NKCe5F0ORuDO4sPmqhvcQ
#    Description: selects from music we've been listening
#
# 225.
#    ID: 4A01B3wh6uv7yOpzYdVLR3
#    Description: No description.
#
# 226. Bread & Dub
#    ID: 4drXxn0GpOXXG6Rp5RvXca
#    Description: Enjoy your morning to great breakfast dub beats.
#
# 227. The Blues Skies
#    ID: 070FVPBKvfu6M5tf4I9rt2
#    Description: The skies are filled with blues for a joyful ride.
#
# 228. It Only Takes Two
#    ID: 5McngUiuALFIS4VVF4oko5
#    Description: No, not to tango... to write an awesome rock song! These duos know how to make a lot out of what ...
#
# 229. Historic Venue: Ryman Auditorium
#    ID: 2lOMjzyPMlcIvcaWlaF6MB
#    Description: Transport yourself to the "Mother Church of Country Music" with these live cuts from the Ryman.
#
# 230. Vocal Acrobats
#    ID: 2JskSjr3Rl0LAv05L0hjV4
#    Description: Let these singers tug on your heartstrings with their amazing vocal performances.
#
# 231. Macy's Thanksgiving Day Parade 2013
#    ID: 0TmNZR8QmL60k1gWWa37fg
#    Description: Catch up on all the performers at the 2013 Macy's Thanksgiving Day Parade.
#
# 232. Austin Sounds
#    ID: 2d96NZvM6U7G14LDQdNfwS
#    Description: SXSW has deep roots in Austin. Get a sense of the city and all its sounds.
#
# 233. Sunset in Austin
#    ID: 1MXbpQ8OiNsYtQxiXexPJ7
#    Description: The sun is setting and the night takes over. Enjoy these while letting the evening play on.
#
# 234. Kanye To The
#    ID: 6Sz7KT9MhChZuAJDKEWiLF
#    Description: Some soulful sets from Ye plus contributions to soul. Please enjoy this curated set entitled &quo...
#
# 235. Found Them First
#    ID: 3sJ6SlgRo56Oa7YhHcLK5l
#    Description: What artists have been your favorite new finds this year? Check out a sampling of our favorites h...
#
# 236. New Year's 2015
#    ID: 2FjbiwWYHqEifO3VY5LYP8
#    Description: A toast to all the artists who will be performing on New Year&#x27;s Eve across the globe.
#
# 237. A Bite Out Of The Afternoon
#    ID: 3uDgik1xOhjYVsXucW7GEb
#    Description: Grab your food, turn on the easy hip-hop and enjoy.
#
# 238. Girls Night Out
#    ID: 1Bxi8UJlVM7tLYDMOqsYYF
#    Description: The ultimate playlist to get you ready for a fun night out with your girlfriends.
#
# 239. Power Hour
#    ID: 7wiCMbRM2F6PQYGLwnJ7GJ
#    Description: Pre-game music to get you pumped up before heading out for the night.
#
# 240. Let Loose
#    ID: 3Nh594yQ7PkhEPzUUAKlnH
#    Description: It's the weekend and you need some popular songs to hang out with. We've got you covered.
#
# 241. Foam Party
#    ID: 3L1KIXcFcHhfeMlf7pD7IB
#    Description: An epic event in the making. You can not enjoy a Foam party without the perfect songs to get ever...
#
# 242. An Epic Evening
#    ID: 6wz9sFJRqsmu7ldv0xJOIz
#    Description: It all starts with some friends over for dinner but after a couple of drinks... well let's just s...
#
# 243. Falling In Love
#    ID: 08vPKM3pmoyF6crB2EtASQ
#    Description: Sometimes only music can describe that feeling...
#
# 244. Early Morning Rise
#    ID: 68oeNrImf1nxjL0RbpZkij
#    Description: Chill songs for lazy mornings. You'll roll out of bed and get the coffee on, eventually ...
#
# 245. Backstage
#    ID: 5qVqzAenJiKLfRny06XQf0
#    Description: Help the band set-up and get ready for the best live performances from your favorite artists.
#
# 246. Bullet for Hell
#    ID: 1RKtKRcejWjN6ZOkghImIV
#    Description: Slipknot, Mudvayne, Hatebreed. Turn the volume all the way up.
#
# 247. Grand Hustle Gang Spotify Picks
#    ID: 4C0S1zvtcMtk2notLxCL1J
#    Description: Grand Hustle Gang top picks chosen by Spotify.
#
# 248. MMG Spotify Picks
#    ID: 2nZndNnauO6SID8cjf4C9F
#    Description: MMG top picks chosen by Spotify.
#
# 249. Shady Records Spotify Picks
#    ID: 3hR94iGaotWbCFv5eDe0gZ
#    Description: Shady Records top picks chosen by Spotify.
#
# 250. Taylor Gang Spotify Picks
#    ID: 5VvCwhF9WqXKUaJLtJfeXn
#    Description: Taylor Gang top picks chosen by Spotify.
#
# 251. country 90's
#    ID: 6SGM9ZiMSfayAmJMNFlX2u
#    Description: No description.
#
# 252. Hours of Ours
#    ID: 54LbSpjd64NjKPUyYAGkNU
#    Description: Beatiful, mellow jazz for romance
#
# 253. Walk a Country Mile
#    ID: 4p3lupatTubTWpTgCZjgpk
#    Description: Countrify your power walk
#
# 254. Honeysuckle Lazy
#    ID: 6tLfPD2P9syvBV8rgO2Yq1
#    Description: No description.
#
# 255. On to Something Good
#    ID: 3FfBohQXFlgFnYubzrvoq4
#    Description: No description.
#
# 256. Back to the Roots
#    ID: 1S4JPQeJxtsN37X8as5EPk
#    Description: Classic folk, bluegrass, country blues, and spirituals, along with some recent songs that have a ...
#
# 257. Beer 'n Burgers
#    ID: 7CHrwiytyubNpnaZqyyUkb
#    Description: Rockabilly and old school rock & roll—the perfect soundtrack to a night of beer and burgers.
#
# 258. Bossa Nova
#    ID: 4LmOnbOmtMUyQQjo6L9mct
#    Description: Enjoy the sweet rhythms of bossa nova - the perfect marriage of samba and jazz.
#
# 259. King of Pop
#    ID: 653U7cDBXXkPZ07Xk8kxL6
#    Description: As one of the most widely beloved entertainers of all-time, Michael Jackson made an unforgettable...
#
# 260. The Jazz Escape
#    ID: 7hjaw2oDqkMS2uDk5vmzAu
#    Description: Escape the world with the best, most relaxing Jazz.
#
# 261. Workday - Country
#    ID: 6MtNKlWguIlTJ6Q7WAcDtU
#    Description: Get through your workday with 8 hours of country music.
#
# 262. Workday - Singer-songwriter
#    ID: 3TurM2x1HaeNEztqBnomV6
#    Description: Get through your workday with 8 hours of singer-songwriter tunes.
#
# 263. Tunigo Live
#    ID: 5rqcJUB5ox8BK3L3Ki7gfF
#    Description: No description.
#
# 264. Top Picks Toplists
#    ID: 4lCv0oN3gPxoqvXmA3cDjS
#    Description: No description.
#
# 265. Top Picks Pop
#    ID: 3xGWOQUB6jgHd4PLVQvbfG
#    Description: No description.
#
# 266. Top Picks Decades
#    ID: 0q2dbyUyAuUkW3ec6XRwJD
#    Description: No description.
#
# 267. Top Picks Workout
#    ID: 45mRKVQrL1pK9tbRp25yro
#    Description: No description.
#
# 268. Top Picks Mood
#    ID: 1EQVvrXxgoWdqUHni1LOgm
#    Description: No description.
#
# 269. Top Picks Kids
#    ID: 4ruhrP9ntTdDMpjrk22v9u
#    Description: No description.
#
# 270. Top Picks Classical
#    ID: 3jh9R9uXIoozPA0uccJt2C
#    Description: No description.
#
# 271. Top Picks Pop Culture
#    ID: 5QZZbWjNVjynssxTuO3f0f
#    Description: No description.
#
# 272. Top Picks Party
#    ID: 2WIkzIBRwM9wRD9innJ8b7
#    Description: No description.
#
# 273. Top Picks Chill
#    ID: 2b5yd7Ox7vb4OcPOOVYwFZ
#    Description: No description.
#
# 274. Top Picks Urban
#    ID: 6spPs4oxQEPSWXyXzqg8CR
#    Description: No description.
#
# 275. Top Picks Club
#    ID: 285xVjuyHG2CusStdc8kCS
#    Description: No description.
#
# 276. Top Picks Country
#    ID: 7hx7ugiU2MaeXOjQRVDzdk
#    Description: No description.
#
# 277. Top Picks Events
#    ID: 2Mecjd64RGHE4vLDMuX88V
#    Description: No description.
#
# 278. Top Picks Groove
#    ID: 38ZGEwSsiHoOEOu446h75W
#    Description: No description.
#
# 279. Top Picks Rock
#    ID: 5QOzTki17fEWKoUVcvTrI2
#    Description: No description.
#
# 280. Top Picks Romance
#    ID: 4tSzT9BRuf3qRJDbPz4SlS
#    Description: No description.
#
# 281. Top Picks Jazz and Blues
#    ID: 5LrQkRUFFuKWAJCECd2X9y
#    Description: No description.
#
# 282. Top Picks Travel
#    ID: 4NAi06Izmj4CPqmMuY1RsE
#    Description: No description.
#
# 283. Top Picks holiday
#    ID: 4uLnCAHJw65SyFXXmBSuc0
#    Description: No description.
#
# 284. Undiscovered bands
#    ID: 2ZMfoURN2ZwapN17Yb5d1k
#    Description: No description.
#
# 285. Women of Sweden
#    ID: 2EaYMuzaVSdPjJOqg77E2E
#    Description: Det finns hur många drottningar av Sverige som helst. Vi har samlat 100 av dem i en spellista, dä...
#
# 286. Kvinnor att ha koll på 2014
#    ID: 1m6DKwKNM1YLcm3OX6RzJg
#    Description: Upptäck svenska talanger som kommer att vara soundtracket till ditt 2014.  En spellista som ständ...
#
# 287. 38 Great Female Duets
#    ID: 1xAmEtLT8c17IisGUa1f4M
#    Description: 38 great tunes by female singers only!
#
# 288. Best of Boybands and Girl Groups
#    ID: 7oTMBMLu6EI4l163C9fkhg
#    Description: Remember the glory days when boy bands and girl groups ruled the radio? Listen to this playlist a...
#
# 289. Johnossi
#    ID: 5MkJ5KSzz4wmCpIFvM6pFT
#    Description: Missa inte Johnossi på Flamingo-scenen på TORSDAG / 18.45
#
# 290. Håkan Hellström
#    ID: 2CTBt2glXb1wEzUa6wCbWU
#    Description: Missa inte Håkan Hellström på Flamingo-scenen på FREDAG / 19.40
#
# 291. Rodriguez
#    ID: 52JrW4dL2mDe1Dneq0vH1I
#    Description: Missa inte Rodriguez på Flamingo-scenen på FREDAG / 15.00
#
# 292. Of Monsters and Men
#    ID: 4pL8YJw0ts5YcpxEgl1LiL
#    Description: Missa inte Of Monsters and Men på Azalea-scenen på FREDAG / 16.10
#
# 293. Alicia Keys
#    ID: 3zxOlGe8vWwQA8eLRXBqTY
#    Description: Missa inte Alicia Keys på Flamingo-scenen på LÖRDAG / 22.20
#
# 294. Daniel Adams-Ray
#    ID: 6c51ZkUk7wO3Icy2sW3jvA
#    Description: Missa inte Daniel Adams-Ray på Flamingo-scenen på TORSDAG / 16.35
#
# 295. Kendrick Lamar
#    ID: 4lwqQxljF1Rge3X4eMzdza
#    Description: Missa inte Kendrick Lamar på Azalea-scenen på LÖRDAG / 21.00
#
# 296. Disclosure
#    ID: 5grxWts6M4gvPZFrWSNOBl
#    Description: Missa inte Disclosure på Linné-scenen på LÖRDAG / 23.00
#
# 297. Miguel
#    ID: 67zOV0qxT0TT8JEHZDCBDd
#    Description: Missa inte Miguel på Azalea-scenen på FREDAG / 21.15
#
# 298. Welcome Home
#    ID: 0LqjAibgbS9ep32zZrDcAN
#    Description: Finally that person that we've missed so much is home. This deserves  a party!
#
# 299. Kids B-day Party
#    ID: 6PzNMpCPMDMo1pOUjNhDUC
#    Description: The perfect playlist for a great party. Fun, happy, joyful... the kids will love it!
#
# 300. Walk The Dog
#    ID: 2mADaSxlIcxRDSG9e9vLlh
#    Description: Songs for you and your best friend. Endless love in any weather.
#
# 301. Tagga För OS
#    ID: 0uZg7go8TKu5hpv1L6CJ4y
#    Description: Samla dina vänner och ladda inför de Olypiska Spelen. Nu kör vi!
#
# 302. Commuter Flow (That Fire For Your Aux Cord)
#    ID: 5wPUMOWXlhmk9XmGO4RtKz
#    Description: Some nice little jams to make the ride smooth. To quote Dom Kennedy &quot;Pleeze Make It Home Saf...
#
# 303. Annorlunda Kärlekslåtar
#    ID: 1cddSHoeIrE3m0i8TqYNbn
#    Description: No description.
#
# 304. Fuck Valentine!
#    ID: 5Dn14a8hNIhT3NLLjUUBGL
#    Description: No description.
#
# 305. Valentine anger
#    ID: 1apRF10Iufr0NBBiF1u7E5
#    Description: No description.
#
# 306. Det är så tråkigt och trist utan dig
#    ID: 7qeSmszUjRBWOwHzlxfEXt
#    Description: No description.
#
# 307. Inget är större än KÄRLEKEN
#    ID: 2PMlGn5a2jxukdhCYQyQvG
#    Description: No description.
#
# 308. Folk & Rock 200 favoriter
#    ID: 3cC0Hnr7idCemR4JxOh2lI
#    Description: Borlängeprofilen Ingemar Magnusson, som till vardags driver skivbutiken Folk å Rock, listar sina ...
#
# 309. The Critics Choice 2012
#    ID: 24HEIuw8etbkitpDCxZ1dQ
#    Description: A playlist with songs from the best reviewed albums in Sweden 2012.
#
# 310. EM Fotboll 2012
#    ID: 0NYlvGXveeyvhb5G80LPtA
#    Description: Älskade fotbollslåtar, samlade i en spellista. Officiella mästerskapslåtar, varvat med inofficiel...
#
# 311. Way Out West 2013
#    ID: 2IBmQa3jJULanJldYav1jW
#    Description: No description.
#
# 312. Sweden Rock 2013
#    ID: 3PNltrHQaYdqO0FdTAZ3wB
#    Description: No description.
#
# 313. Metaltown 2013
#    ID: 7LxjY6mdINPgSVhILU2nk6
#    Description: No description.
#
# 314. Hultsfred 2013
#    ID: 0pTJgTL7GIhxto5z35Rfwu
#    Description: No description.
#
# 315. Putte i Parken 2013
#    ID: 3JqYduMX06DjhsJRBG4kN5
#    Description: No description.
#
# 316. Getaway Rock 2013
#    ID: 4ftQXs8PU4QMqPLMaJG7QT
#    Description: No description.
#
# 317. Bråvalla Festival 2013
#    ID: 74Wbo0ObpdSDnCIGvEDHOk
#    Description: No description.
#
# 318. Peace & Love 2013
#    ID: 5Q9dGaDLzwijaWkI4yFfSk
#    Description: No description.
#
# 319. Sonisphere
#    ID: 2fC7gpl3V9MmCc8gBPHc66
#    Description: No description.
#
# 320. Gainsville Stockholm 2012
#    ID: 6ClBNzH2PMh2jvkEuSFBFJ
#    Description: No description.
#
# 321. Ystad Sweden Jazzfestival 2012
#    ID: 0DH66SG2vZ7dIocTxxA5q9
#    Description: Ystad Jazzfestival arrangeras i sommar för tredje gången. 2012 års festival går av stapeln den 2:...
#
# 322. Storsjöyran 2012
#    ID: 2XQnLAZo27gz7VGRBl34l9
#    Description: Storsjöyran är Sveriges äldsta stadsfestival, grundad 1963. Sommarens festival arrangeras 27 - 28...
#
# 323. Emmaboda 2012
#    ID: 4muFXNJjmJvLWdHmx0PKYO
#    Description: Emmabodafestivalen har sedan arrangerats sedan 1988 av den ideella föreningen Vinterbadarna. Somm...
#
# 324. Stockholm Music & Arts 2012
#    ID: 6lrsZHHFL65pjpDcjv6sFi
#    Description: Stockholm Music & Arts är en ny festival som i sommar, den 3 - 5 augusti, arrangeras för första g...
#
# 325. Popaganda 2012
#    ID: 0mJut6QO3dUUAOJlBPujT1
#    Description: Popaganda jubilerar, då festivalen nu fyller 10 år. Sommarens upplaga arrangeras vid Eriksdalsbad...
#
# 326. Metaltown 2012
#    ID: 6cSO5pHOCQxoEiXYDPa3Uq
#    Description: Metaltown är en av Sveriges största och mest populära hårdrock/metal-festivaler. Årets festival ä...
#
# 327. Urkult 2012
#    ID: 7b1rMSnmiYfj8nH8spIjxF
#    Description: Första helgen i augusti går folk- och världsmusikfestivalen Urkult av stapeln för 18:e året i rad...
#
# 328. Sweden Rock Festival 2012
#    ID: 2xxkK8eaOyM6JRhHOheZBZ
#    Description: Sweden Rock är Sveriges största hårdrocksfestival. Sommarens upplaga äger rum 6 - 9 juni i Sölves...
#
# 329. Hultsfred 2012
#    ID: 26yS4HN010lrCBBlCbjF2b
#    Description: Hultsfredsfestivalen 2012 går av stapeln den 14:e juni och pågår t.om. den 16:e. Hitta spellistor...
#
# 330. Putte i parken 2012
#    ID: 5eRHTcvWyEU0MEzNOiR2j1
#    Description: Putte i Parken arrangeras i år för femte året i rad. Sommarens festival går av stapeln den 4 - 7 ...
#
# 331. Getaway Rock 2012
#    ID: 4mM7tVGeVv4dOFPTlftofk
#    Description: Getaway Rock Festival är efter två år etablerad som en av Sveriges bästa och viktigaste rockfesti...
#
# 332. Peace & Love 2012
#    ID: 7DcfXNVB5WpzYwCkqBaVDx
#    Description: Peace & Love 2012 arrangeras 26 - 30 juni i Borlänge. Temat för sommarens festival är "En ny värl...
#
# 333. Sveriges Nationaldag
#    ID: 33eWAE7F4bBUAjGtJVtCYB
#    Description: För att fira de blå/gula färgerna har vi grävt djupt i den svenska låtskatten och sammanställt en...
#
# 334. New year's eve by Icona Pop
#    ID: 3ukqAcaahACMyRzpkwHXew
#    Description: No description.
#
# 335. Swing in the New Year
#    ID: 5zyeLrOc31CPX7uk9xNL7y
#    Description: Ring in the new year to the sweet sound of jazz and blues.
#
# 336. Alternative New Year's Eve
#    ID: 214Nwj78JwTfjSeQxbGxeX
#    Description: A different option for your New Year's Eve party. Sweet pop, rock, and singer/songwriter tunes ab...
#
# 337. Raw Expression
#    ID: 3yUO32lGCEnAfFGORSEsy4
#    Description: Brukout edition: It's a raw and sexy dancehall party!
#
# 338. Intervju med Seinabo Sey
#    ID: 2k9EArKbf7N3QUmuNJHSo8
#    Description: Stjärnskottet Seinabo Sey berättar historien bakom sin uppmärksammade debutsingel "Younger", och ...
#
# 339. The official Bråvalla Festival playlist 2017
#    ID: 5sk53m6HgZorO1RDUkaiIZ
#    Description: All confirmed artists at the Bråvalla Festival 2017! June 28th - July 1st, Norrköping, Sweden. <a...
#
# 340. International Playboy
#    ID: 73boXMJz9iBoXxQVFZ94r5
#    Description: If you travel the world and the seven seas, cashing six figure checks in all currencies, this pla...
#
# 341. National Blood Week
#    ID: 2y74Ha0ztRUcIYmqITh0D4
#    Description: No description.
#
# 342. Most Listened To British Dads on Spotify
#    ID: 1k9jG0FUp7BcrAF1MZSabO
#    Description: No description.
#
# 343. dw-c
#    ID: 5ji4GZJpll6twskFvKxiHx
#    Description: No description.
#
# 344. dw_g
#    ID: 40VxbK9NqccdUDUpiUXmbp
#    Description: No description.
#
# 345. Top Shower Songs
#    ID: 0RTz1jFo5BXGPfI8eVf8sj
#    Description: No description.
#
# 346. foodora dinner playlist
#    ID: 4lgseztVwmKQ8MNETPVIny
#    Description: No description.
